# %%
def toLowerCase(s):
  #simply apply the .lower() method
  return s.lower()

# %%
s = "Hello"
toLowerCase(s)
# Out:
# 'hello'

# %%
s = "here"
toLowerCase(s)
# Out:
# 'here'

# %%
s = "LOVELY"
toLowerCase(s)
# Out:
# 'lovely'
