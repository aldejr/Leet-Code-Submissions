# %%
def threeConsecutiveOdds(arr):
  final = False
  for i in range(len(arr)):
    if arr[i] % 2 != 0:
      check = arr[i:i+3]
      odds = []
      for num in check[1:]:
        if num % 2 != 0:
          odds.append(num)
        else:
          pass
      if len(odds) == 2:
        final = True
        break
      else:
        pass
    else:
      pass
  return final

# %%
#Test Case 1
arr = [2,6,4,1]
threeConsecutiveOdds(arr)
# Out:
# False

# %%
#Test Case 2
arr = [1,2,34,3,4,5,7,23,12]
threeConsecutiveOdds(arr)
# Out:
# True
