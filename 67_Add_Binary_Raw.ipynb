# %%
a = "11"
b = "1"

addend1 = int(a,2)
addend2 = int(b,2)

print(bin(addend1+addend2)[2:])
# Out:
# 100

# %%
def addBinary(a,b):
  addend1 = int(a,2)
  addend2 = int(b,2)
  return bin(addend1+addend2)[2:]
