# %%
def getConcatenation(nums):
  #Make the list twice what it was
  return nums * 2

# %%
nums = [1,2,1]
getConcatenation(nums)
# Out:
# [1, 2, 1, 1, 2, 1]

# %%
nums = [1,3,2,1]
getConcatenation(nums)
# Out:
# [1, 3, 2, 1, 1, 3, 2, 1]
